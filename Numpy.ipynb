# %%
import numpy as np

# %%
data = np.array([[1,2,3],[4,5,6]])
print(data)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(data.shape)
print(data.ndim)
print(data.size)
print(data.dtype)
# Out:
# (2, 3)
# 2
# 6
# int64

# %%
print(data[0,1])
print(data[1,1])
# Out:
# 2
# 5

# %%
data[0,2]=90
print(data)
# Out:
# [[ 1  2 90]
#  [ 4  5  6]]

# %%
print(np.sum(data))
# Out:
# 108

# %%
print(np.sum(data,axis=0))
# Out:
# [ 5  7 96]

# %%
print(np.sum(data,axis=1))
# Out:
# [93 15]

# %%
array= np.array([[1,2],[3,4],[5,6]])
print(array)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
